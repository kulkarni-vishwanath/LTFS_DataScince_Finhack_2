# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("train_fwYjLYX.csv",parse_dates=['application_date'])
test = pd.read_csv("test_1eLl9Yf.csv",parse_dates=['application_date'])

# %%
train_segment1 = train[train['segment'] == 1]
train_segment2 = train[train['segment'] == 2]

test_segment1 = test[test['segment'] == 1]
test_segment2 = test[test['segment'] == 2]

# %%
len(test_segment1)
# Out:
# 87

# %%
train_segment1['branch_id'].nunique()
# Out:
# 83

# %%
test_segment1.append([test_segment1]*2,ignore_index=True)
# Out:
#      id application_date  segment
# 0     1       2019-07-06        1
# 1     2       2019-07-07        1
# 2     3       2019-07-08        1
# 3     4       2019-07-09        1
# 4     5       2019-07-10        1
# 5     6       2019-07-11        1
# 6     7       2019-07-12        1
# 7     8       2019-07-13        1
# 8     9       2019-07-14        1
# 9    10       2019-07-15        1
# 10   11       2019-07-16        1
# 11   12       2019-07-17        1
# 12   13       2019-07-18        1
# 13   14       2019-07-19        1
# 14   15       2019-07-20        1
# 15   16       2019-07-21        1
# 16   17       2019-07-22        1
# 17   18       2019-07-23        1
# 18   19       2019-07-24        1
# 19   20       2019-07-25        1
# 20   21       2019-07-26        1
# 21   22       2019-07-27        1
# 22   23       2019-07-28        1
# 23   24       2019-07-29        1
# 24   25       2019-07-30        1
# 25   26       2019-07-31        1
# ...
